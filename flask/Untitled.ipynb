# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logging
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten, Dropout, Reshape

logging.info("모델 시작")
data = pd.read_csv("../flask/data.csv")

# %%
# 데이터 프레임으로 변환
df = pd.DataFrame(data)

# 데이터 전처리
df['candle_date_time_kst'] = pd.to_datetime(df['candle_date_time_kst'], format='%Y-%m-%dT%H:%M:%S')
df.set_index('candle_date_time_kst', inplace=True)

# %%
df.head()
# Out:
#                       opening_price  high_price   low_price  trade_price
# candle_date_time_kst
# 2023-05-23 15:06:00      36411000.0  36412000.0  36410000.0   36411000.0  \
# 2023-05-23 15:06:00      36411000.0  36412000.0  36408000.0   36410000.0
# 2023-05-23 15:06:00      36411000.0  36412000.0  36408000.0   36410000.0
# 2023-05-23 15:06:00      36411000.0  36421000.0  36408000.0   36409000.0
# 2023-05-23 15:06:00      36411000.0  36428000.0  36408000.0   36425000.0
#
#                       candle_acc_trade_price  candle_acc_trade_volume
# candle_date_time_kst
# 2023-05-23 15:06:00             9.829872e+05                 0.026997
# 2023-05-23 15:06:00             7.743630e+06                 0.212684
# 2023-05-23 15:06:00             7.878793e+06                 0.216396
# 2023-05-23 15:06:00             2.042277e+07                 0.560879
# 2023-05-23 15:06:00             4.670044e+07                 1.282337

# %%
# 데이터 프레임 확인
print(df.head())  # 처음 몇 개의 행 출력
print(df.info())  # 데이터 프레임의 구조 및 열의 정보 출력
# Out:
#                       opening_price  high_price   low_price  trade_price
# candle_date_time_kst
# 2023-05-23 15:06:00      36411000.0  36412000.0  36410000.0   36411000.0  \
# 2023-05-23 15:06:00      36411000.0  36412000.0  36408000.0   36410000.0
# 2023-05-23 15:06:00      36411000.0  36412000.0  36408000.0   36410000.0
# 2023-05-23 15:06:00      36411000.0  36421000.0  36408000.0   36409000.0
# 2023-05-23 15:06:00      36411000.0  36428000.0  36408000.0   36425000.0
#
#                       candle_acc_trade_price  candle_acc_trade_volume
# candle_date_time_kst
# 2023-05-23 15:06:00             9.829872e+05                 0.026997
# 2023-05-23 15:06:00             7.743630e+06                 0.212684
# 2023-05-23 15:06:00             7.878793e+06                 0.216396
# 2023-05-23 15:06:00             2.042277e+07                 0.560879
# 2023-05-23 15:06:00             4.670044e+07                 1.282337
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 30 entries, 2023-05-23 15:06:00 to 2023-05-23 15:08:00
# Data columns (total 6 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   opening_price            30 non-null     float64
#  1   high_price               30 non-null     float64
#  2   low_price                30 non-null     float64
#  3   trade_price              30 non-null     float64
#  4   candle_acc_trade_price   30 non-null     float64
#  5   candle_acc_trade_volume  30 non-null     float64
# dtypes: float64(6)
# memory usage: 1.6 KB
# None

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Reshape, LSTM, Dense
import datetime

# 데이터 정규화
scaler = MinMaxScaler()
scale_cols = ['opening_price', 'high_price', 'low_price', 'trade_price', 'candle_acc_trade_price', 'candle_acc_trade_volume']
scaled = scaler.fit_transform(df[scale_cols])

# 데이터셋 생성
def create_dataset(data, target, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps)])
        y.append(target[i + time_steps])
    return np.array(X), np.array(y)



# 데이터 분할 비율
train_ratio = 0.6  # 학습 데이터 비율을 60%로 설정
val_ratio = 0.2    # 검증 데이터 비율을 20%로 설정
test_ratio = 0.2   # 테스트 데이터 비율을 20%로 설정

# 학습 데이터와 테스트 데이터 분할
test_data_size = int(len(scaled) * test_ratio)
train_val_data = scaled[:-test_data_size]
test_data = scaled[-test_data_size:]

# 학습 데이터와 검증 데이터 분할
val_data_size = int(len(train_val_data) * val_ratio / (train_ratio + val_ratio))
train_data = train_val_data[:-val_data_size]
val_data = train_val_data[-val_data_size:]

n_timesteps = 4

# 학습 데이터셋 생성
X_train, y_train = create_dataset(train_data, train_data[:, 3], n_timesteps)

# 검증 데이터셋 생성
X_val, y_val = create_dataset(val_data, val_data[:, 3], n_timesteps)

# 테스트 데이터셋 생성
X_test, y_test = create_dataset(test_data, test_data[:, 3], n_timesteps)

# %%
# 학습 데이터셋 생성
X_train, y_train = create_dataset(train_data, train_data[:, 3], n_timesteps)
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)

# 검증 데이터셋 생성
X_val, y_val = create_dataset(val_data, val_data[:, 3], n_timesteps)
print("X_val shape:", X_val.shape)
print("y_val shape:", y_val.shape)

# 테스트 데이터셋 생성
X_test, y_test = create_dataset(test_data, test_data[:, 3], n_timesteps)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (14, 4, 6)
# y_train shape: (14,)
# X_val shape: (2, 4, 6)
# y_val shape: (2,)
# X_test shape: (2, 4, 6)
# y_test shape: (2,)

# %%
n_features = len(scale_cols)

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))
model.add(Dropout(0.025))
model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model.add(Dropout(0.025))
model.add(Flatten())
model.add(Dense(64, activation='relu'))  # Add Dense layer to match the number of features
model.add(Reshape((-1, 64)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

# 모델 학습하기
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32)

# 모델 평가하기
score = model.evaluate(X_test, y_test)

# 모델 예측하기
y_pred = model.predict(X_test)

last_sequence = scaled[-n_timesteps:]
last_sequence = np.expand_dims(last_sequence, axis=0)
#future_pred = model.predict(last_sequence)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.2700 - val_loss: 0.0140
# Epoch 2/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2531 - val_loss: 0.0114
# Epoch 3/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2407 - val_loss: 0.0090
# Epoch 4/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2251 - val_loss: 0.0066
# Epoch 5/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.2114 - val_loss: 0.0043
# Epoch 6/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1942 - val_loss: 0.0023
# Epoch 7/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1789 - val_loss: 7.1051e-04
# Epoch 8/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1622 - val_loss: 1.2884e-05
# Epoch 9/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1399 - val_loss: 5.3458e-04
# Epoch 10/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.1196 - val_loss: 0.0029
# Epoch 11/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0992 - val_loss: 0.0080
# Epoch 12/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0766 - val_loss: 0.0170
# Epoch 13/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0589 - val_loss: 0.0317
# Epoch 14/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0442 - val_loss: 0.0539
# Epoch 15/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0405 - val_loss: 0.0828
# Epoch 16/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0419 - val_loss: 0.1116
# Epoch 17/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0649 - val_loss: 0.1287
# Epoch 18/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0708 - val_loss: 0.1281
# Epoch 19/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0733 - val_loss: 0.1154
# Epoch 20/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0664 - val_loss: 0.0984
# Epoch 21/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0488 - val_loss: 0.0812
# Epoch 22/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0416 - val_loss: 0.0661
# Epoch 23/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0341 - val_loss: 0.0542
# Epoch 24/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0351 - val_loss: 0.0452
# Epoch 25/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0379 - val_loss: 0.0385
# Epoch 26/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0422 - val_loss: 0.0339
# Epoch 27/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0437 - val_loss: 0.0309
# Epoch 28/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0441 - val_loss: 0.0294
# Epoch 29/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0419 - val_loss: 0.0290
# Epoch 30/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0434 - val_loss: 0.0297
# Epoch 31/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0464 - val_loss: 0.0314
# Epoch 32/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0417 - val_loss: 0.0342
# Epoch 33/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0433 - val_loss: 0.0379
# Epoch 34/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0351 - val_loss: 0.0426
# Epoch 35/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0358 - val_loss: 0.0481
# Epoch 36/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0332 - val_loss: 0.0542
# Epoch 37/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0296 - val_loss: 0.0609
# Epoch 38/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0308 - val_loss: 0.0669
# Epoch 39/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0308 - val_loss: 0.0718
# Epoch 40/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0337 - val_loss: 0.0747
# Epoch 41/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0340 - val_loss: 0.0748
# Epoch 42/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0309 - val_loss: 0.0728
# Epoch 43/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0363 - val_loss: 0.0689
# Epoch 44/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0350 - val_loss: 0.0642
# Epoch 45/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0284 - val_loss: 0.0591
# Epoch 46/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0295 - val_loss: 0.0539
# Epoch 47/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0297 - val_loss: 0.0494
# Epoch 48/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0299 - val_loss: 0.0457
# Epoch 49/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0294 - val_loss: 0.0431
# Epoch 50/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0274 - val_loss: 0.0414
# Epoch 51/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0309 - val_loss: 0.0404
# Epoch 52/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0294 - val_loss: 0.0405
# Epoch 53/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0258 - val_loss: 0.0412
# Epoch 54/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0279 - val_loss: 0.0427
# Epoch 55/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0299 - val_loss: 0.0446
# Epoch 56/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0291 - val_loss: 0.0465
# Epoch 57/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0277 - val_loss: 0.0479
# Epoch 58/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0270 - val_loss: 0.0489
# Epoch 59/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0305 - val_loss: 0.0486
# Epoch 60/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0233 - val_loss: 0.0482
# Epoch 61/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0280 - val_loss: 0.0470
# Epoch 62/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0295 - val_loss: 0.0450
# Epoch 63/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0256 - val_loss: 0.0425
# Epoch 64/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0244 - val_loss: 0.0404
# Epoch 65/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0246 - val_loss: 0.0385
# Epoch 66/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0244 - val_loss: 0.0372
# Epoch 67/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0239 - val_loss: 0.0362
# Epoch 68/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0252 - val_loss: 0.0360
# Epoch 69/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0234 - val_loss: 0.0362
# Epoch 70/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0252 - val_loss: 0.0370
# Epoch 71/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0214 - val_loss: 0.0382
# Epoch 72/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0245 - val_loss: 0.0398
# Epoch 73/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0250 - val_loss: 0.0413
# Epoch 74/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0257 - val_loss: 0.0418
# Epoch 75/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0231 - val_loss: 0.0417
# Epoch 76/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0239 - val_loss: 0.0412
# Epoch 77/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0215 - val_loss: 0.0401
# Epoch 78/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0187 - val_loss: 0.0389
# Epoch 79/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0245 - val_loss: 0.0378
# Epoch 80/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0244 - val_loss: 0.0368
# Epoch 81/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0200 - val_loss: 0.0356
# Epoch 82/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0232 - val_loss: 0.0342
# Epoch 83/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0213 - val_loss: 0.0330
# Epoch 84/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0188 - val_loss: 0.0326
# Epoch 85/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0241 - val_loss: 0.0324
# Epoch 86/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0224 - val_loss: 0.0329
# Epoch 87/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0205 - val_loss: 0.0339
# Epoch 88/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0197 - val_loss: 0.0350
# Epoch 89/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0182 - val_loss: 0.0358
# Epoch 90/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0220 - val_loss: 0.0364
# Epoch 91/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0207 - val_loss: 0.0359
# Epoch 92/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0198 - val_loss: 0.0346
# Epoch 93/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0165 - val_loss: 0.0335
# Epoch 94/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0189 - val_loss: 0.0328
# Epoch 95/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0152 - val_loss: 0.0326
# Epoch 96/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0161 - val_loss: 0.0327
# Epoch 97/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0150 - val_loss: 0.0330
# Epoch 98/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0164 - val_loss: 0.0334
# Epoch 99/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0154 - val_loss: 0.0341
# Epoch 100/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0178 - val_loss: 0.0350
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0153
# 1/1 [==============================] - 0s 153ms/step

# %%
def reverse_min_max_scaling(org_x, x):
    org_x_np = np.asarray(org_x)
    x_np = np.asarray(x)
    return (x_np * (org_x_np.max() - org_x_np.min() + 1e-7)) + org_x_np.min()
# 예측 결과 역변환
y_pred_reshaped = np.reshape(y_pred, (-1, 1))
y_pred_original = reverse_min_max_scaling(df['trade_price'], y_pred_reshaped)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 10
#       7 y_pred_original = reverse_min_max_scaling(df['trade_price'], y_pred_reshaped)
#       9 y_pred_dict['dateday'] = list(y_pred_dict['dateday'])
# ---> 10 y_pred_dict['prediction'] = list(y_pred_dict['prediction'])
#
# TypeError: 'float' object is not iterable

# %%
# 미래 날짜 계산
current_date = df.index[-1].to_pydatetime()
future_dates = [current_date + datetime.timedelta(hours=i+1) for i in range(1)]

# 예측 결과를 저장할 딕셔너리
y_pred_dict = {
    'dateday': future_dates,
    'prediction': [y_pred_original.flatten()[0]]
}


print(y_pred_dict)
# Out:
# {'dateday': [datetime.datetime(2023, 5, 23, 16, 8)], 'prediction': [36399610.0]}

# %%
import pymysql

def mysql_connection(y_pred_dict):
    # MySql 연결 설정
    connection = pymysql.connect(
        host='localhost',
        user='root',
        password='1234',
        database='bitcoin'
    )

    # 커서 생성
    cursor = connection.cursor()

    # 데이터 삽입 쿼리
    sql = "INSERT INTO predictions (dateday, prediction) VALUES (%s, %s)"

    # 데이터 삽입 실행
    for date, pred in zip(y_pred_dict['dateday'], y_pred_dict['prediction']):
        cursor.execute(sql, (date, pred))

    # 변경 사항 저장
    connection.commit()

    # 연결 종료
    cursor.close()
    connection.close()


# 데이터베이스에 삽입
mysql_connection(y_pred_dict)

# %%
y_pred_dict = model_prediction()
mysql_connection(y_pred_dict)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 y_pred_dict = model_prediction()
#       2 mysql_connection(y_pred_dict)
#
# NameError: name 'model_prediction' is not defined

# %%
mysql_connection(y_pred_dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 y_pred_dict = model_prediction()
#       2 mysql_connection(y_pred_dict)
#
# File ~\Desktop\time-series-da-main\flask\model.py:17, in model_prediction()
#      15 def model_prediction():
#      16     logging.info("모델 시작")
# ---> 17     data = pd.read_csv("./data/bitcoin2023_t.csv")
#      19     if data.empty:
#      20         logging.info("데이터 비어있습니다")
#
# File ~\Desktop\time-series-da-main\venv\lib\site-packages\pandas\io\parsers\readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~\Desktop\time-series-da-main\venv\lib\site-packages\pandas\io\parsers\readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~\Desktop\time-series-da-main\venv\lib\site-packages\pandas\io\parsers\readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~\Desktop\time-series-da-main\venv\lib\site-packages\pandas\io\parsers\readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~\Desktop\time-series-da-main\venv\lib\site-packages\pandas\io\common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/bitcoin2023_t.csv'

# %%
def collect_and_predict():
    result = model_prediction()  # model_prediction 함수의 반환값 저장
    if result.empty:
        logging.info("데이터가 비어있습니다.")
        return
    last_dateday = result.index[-1]  # 최신 데이터의 dateday 값
    prediction_value = result['prediction'].iloc[0]  # 최신 예측 값

    y_pred = {'dateday': last_dateday, 'prediction': prediction_value}  # 딕셔너리 생성

    mysql_connection(y_pred)  # 데이터 삽입

# %%
import requests
import time
import pandas as pd

MAX_DATA_COUNT = 30
CSV_FILE_PATH = "data.csv"
COLUMN_NAMES = ['candle_date_time_kst', 'opening_price', 'high_price', 'low_price', 'trade_price', 'candle_acc_trade_price', 'candle_acc_trade_volume']

def upbit_api():
    url = "https://api.upbit.com/v1/candles/minutes/1"
    params = {
        "market": "KRW-BTC",
        "count": 1
    }
    response = requests.get(url, params=params)
    data = response.json()
    return data

def save_data_to_csv(data):
    df = pd.DataFrame(data, columns=COLUMN_NAMES)
    filtered_df = df[df['opening_price'] != 0]
    filtered_df.to_csv(CSV_FILE_PATH, mode='a', header=False, index=False)

def collect_realtime_data():
    while True:
        data = upbit_api()
        save_data_to_csv(data)
        check_and_delete_excess_data()
        time.sleep(5)

def check_and_delete_excess_data():
    df = pd.read_csv(CSV_FILE_PATH)
    if len(df) > MAX_DATA_COUNT:
        df = df.tail(MAX_DATA_COUNT)
        df.to_csv(CSV_FILE_PATH, index=False)
        print("최대 데이터 개수 초과로 인한 데이터 삭제")

def initialize_csv_file():
    pd.DataFrame(columns=COLUMN_NAMES).to_csv(CSV_FILE_PATH, index=False)
    print("CSV 파일 초기화 완료")

# CSV 파일 초기화 (최초 실행시 한 번만 수행)
initialize_csv_file()
# Out:
# CSV 파일 초기화 완료

# %%
print(data = pd.read_csv('./data.csv'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(data = pd.read_csv('./data.csv'))
#
# TypeError: 'data' is an invalid keyword argument for print()

# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import logging
import datetime
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, LSTM, Dense, Flatten, Dropout, Reshape

data = pd.read_csv('./data.csv')

# 데이터 프레임으로 변환
df = pd.DataFrame(data)

# 데이터 전처리
df['candle_date_time_kst'] = pd.to_datetime(df['candle_date_time_kst'], format='%Y-%m-%dT%H:%M:%S')
df.set_index('candle_date_time_kst', inplace=True)

# 데이터 정규화
scaler = MinMaxScaler()
scale_cols = ['opening_price', 'high_price', 'low_price', 'trade_price', 'candle_acc_trade_price', 'candle_acc_trade_volume']
scaled = scaler.fit_transform(df[scale_cols])

# 데이터셋 생성
def create_dataset(data, target, time_steps=1):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:(i + time_steps)])
        y.append(target[i + time_steps])
    return np.array(X), np.array(y)

# 데이터 분할 비율
train_ratio = 0.6  # 학습 데이터 비율을 60%로 설정
val_ratio = 0.2    # 검증 데이터 비율을 20%로 설정
test_ratio = 0.2   # 테스트 데이터 비율을 20%로 설정

# 학습 데이터와 테스트 데이터 분할
test_data_size = int(len(scaled) * test_ratio)
train_val_data = scaled[:-test_data_size]
test_data = scaled[-test_data_size:]

# 학습 데이터와 검증 데이터 분할
val_data_size = int(len(train_val_data) * val_ratio / (train_ratio + val_ratio))
train_data = train_val_data[:-val_data_size]
val_data = train_val_data[-val_data_size:]

n_timesteps = 4

# 학습 데이터셋 생성
X_train, y_train = create_dataset(train_data, train_data[:, 3], n_timesteps)

# 검증 데이터셋 생성
X_val, y_val = create_dataset(val_data, val_data[:, 3], n_timesteps)

# 테스트 데이터셋 생성
X_test, y_test = create_dataset(test_data, test_data[:, 3], n_timesteps)

# CNN 모델과 LSTM 모델
n_features = len(scale_cols)

model = Sequential()
model.add(Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(n_timesteps, n_features)))
model.add(Dropout(0.025))
model.add(Conv1D(filters=64, kernel_size=2, activation='relu'))
model.add(Dropout(0.025))
model.add(Flatten())
model.add(Dense(64, activation='relu'))  # Add Dense layer to match the number of features
model.add(Reshape((-1, 64)))
model.add(LSTM(100, activation='relu'))
model.add(Dense(1))

model.compile(loss='mse', optimizer='adam')

# 모델 학습하기
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100, batch_size=32)

# 모델 평가하기
score = model.evaluate(X_test, y_test)

# 모델 예측하기
y_pred = model.predict(X_test)
def reverse_min_max_scaling(org_x, x):
    org_x_np = np.asarray(org_x)
    x_np = np.asarray(x)
    return (x_np * (org_x_np.max() - org_x_np.min() + 1e-7)) + org_x_np.min()

# 예측 결과 역변환
y_pred_reshaped = np.reshape(y_pred, (-1, 1))
y_pred_original = reverse_min_max_scaling(df['trade_price'], y_pred_reshaped)

# 미래 날짜 계산
current_date = df.index[-1].to_pydatetime()
future_dates = [current_date + datetime.timedelta(hours=i+1) for i in range(1)]

# 예측 결과를 저장할 딕셔너리
y_pred_dict = {
    'trade_date': future_dates,
    'prediction': [y_pred_original.flatten()[0]]
}
print(y_pred_dict)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 1s/step - loss: 0.1895 - val_loss: 0.2175
# Epoch 2/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1804 - val_loss: 0.2068
# Epoch 3/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1712 - val_loss: 0.1952
# Epoch 4/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1607 - val_loss: 0.1826
# Epoch 5/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1495 - val_loss: 0.1684
# Epoch 6/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1364 - val_loss: 0.1524
# Epoch 7/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1246 - val_loss: 0.1350
# Epoch 8/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1080 - val_loss: 0.1165
# Epoch 9/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0943 - val_loss: 0.0967
# Epoch 10/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0800 - val_loss: 0.0759
# Epoch 11/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0624 - val_loss: 0.0548
# Epoch 12/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0475 - val_loss: 0.0346
# Epoch 13/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0338 - val_loss: 0.0171
# Epoch 14/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0247 - val_loss: 0.0050
# Epoch 15/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0209 - val_loss: 7.2719e-04
# Epoch 16/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0266 - val_loss: 0.0026
# Epoch 17/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0335 - val_loss: 0.0051
# Epoch 18/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0374 - val_loss: 0.0052
# Epoch 19/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0390 - val_loss: 0.0033
# Epoch 20/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0313 - val_loss: 0.0014
# Epoch 21/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0254 - val_loss: 6.1692e-04
# Epoch 22/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0205 - val_loss: 0.0015
# Epoch 23/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0180 - val_loss: 0.0039
# Epoch 24/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0169 - val_loss: 0.0070
# Epoch 25/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0186 - val_loss: 0.0101
# Epoch 26/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0179 - val_loss: 0.0127
# Epoch 27/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0179 - val_loss: 0.0145
# Epoch 28/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0175 - val_loss: 0.0154
# Epoch 29/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0185 - val_loss: 0.0153
# Epoch 30/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0179 - val_loss: 0.0142
# Epoch 31/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0174 - val_loss: 0.0125
# Epoch 32/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0174 - val_loss: 0.0102
# Epoch 33/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0158 - val_loss: 0.0077
# Epoch 34/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0146 - val_loss: 0.0053
# Epoch 35/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0140 - val_loss: 0.0033
# Epoch 36/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0123 - val_loss: 0.0018
# Epoch 37/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0091 - val_loss: 8.4751e-04
# Epoch 38/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0107 - val_loss: 4.3223e-04
# Epoch 39/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0128 - val_loss: 3.3895e-04
# Epoch 40/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0132 - val_loss: 3.3900e-04
# Epoch 41/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0114 - val_loss: 3.2648e-04
# Epoch 42/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0118 - val_loss: 3.0641e-04
# Epoch 43/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0098 - val_loss: 3.6979e-04
# Epoch 44/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0100 - val_loss: 6.2849e-04
# Epoch 45/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0097 - val_loss: 0.0011
# Epoch 46/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0105 - val_loss: 0.0016
# Epoch 47/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0097 - val_loss: 0.0022
# Epoch 48/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0093 - val_loss: 0.0027
# Epoch 49/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0100 - val_loss: 0.0031
# Epoch 50/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0099 - val_loss: 0.0034
# Epoch 51/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0091 - val_loss: 0.0034
# Epoch 52/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0093 - val_loss: 0.0032
# Epoch 53/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0077 - val_loss: 0.0027
# Epoch 54/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0083 - val_loss: 0.0021
# Epoch 55/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0092 - val_loss: 0.0016
# Epoch 56/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0087 - val_loss: 0.0012
# Epoch 57/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0074 - val_loss: 7.7238e-04
# Epoch 58/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0087 - val_loss: 5.0618e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0084 - val_loss: 3.3088e-04
# Epoch 60/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0101 - val_loss: 2.3819e-04
# Epoch 61/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0078 - val_loss: 2.2485e-04
# Epoch 62/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0093 - val_loss: 3.0045e-04
# Epoch 63/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0079 - val_loss: 4.2120e-04
# Epoch 64/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0067 - val_loss: 5.6133e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0073 - val_loss: 7.5655e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0072 - val_loss: 0.0010
# Epoch 67/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0072 - val_loss: 0.0014
# Epoch 68/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0083 - val_loss: 0.0017
# Epoch 69/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0074 - val_loss: 0.0020
# Epoch 70/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0069 - val_loss: 0.0021
# Epoch 71/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0097 - val_loss: 0.0020
# Epoch 72/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0072 - val_loss: 0.0019
# Epoch 73/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0062 - val_loss: 0.0017
# Epoch 74/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0079 - val_loss: 0.0015
# Epoch 75/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0065 - val_loss: 0.0013
# Epoch 76/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0055 - val_loss: 9.7799e-04
# Epoch 77/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0049 - val_loss: 6.7664e-04
# Epoch 78/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0067 - val_loss: 4.3686e-04
# Epoch 79/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0065 - val_loss: 2.8246e-04
# Epoch 80/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0065 - val_loss: 3.1065e-04
# Epoch 81/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0055 - val_loss: 4.2561e-04
# Epoch 82/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0070 - val_loss: 5.7531e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0059 - val_loss: 8.2003e-04
# Epoch 84/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0064 - val_loss: 0.0012
# Epoch 85/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0058 - val_loss: 0.0014
# Epoch 86/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0052 - val_loss: 0.0017
# Epoch 87/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0063 - val_loss: 0.0018
# Epoch 88/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0073 - val_loss: 0.0017
# Epoch 89/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0047 - val_loss: 0.0014
# Epoch 90/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0063 - val_loss: 0.0010
# Epoch 91/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0047 - val_loss: 8.1559e-04
# Epoch 92/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0050 - val_loss: 7.9397e-04
# Epoch 93/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0058 - val_loss: 8.7021e-04
# Epoch 94/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0044 - val_loss: 0.0011
# Epoch 95/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0048 - val_loss: 0.0015
# Epoch 96/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0060 - val_loss: 0.0019
# Epoch 97/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0039 - val_loss: 0.0020
# Epoch 98/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0036 - val_loss: 0.0020
# Epoch 99/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0049 - val_loss: 0.0016
# Epoch 100/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0023 - val_loss: 0.0013
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0087
# 1/1 [==============================] - 0s 157ms/step
# {'trade_date': [datetime.datetime(2023, 5, 9, 12, 40)], 'prediction': [37131132.0]}

# %%
print(y_pred_dict)
# Out:
# {'trade_date': [datetime.datetime(2023, 5, 9, 12, 40)], 'prediction': [37131132.0]}

# %%
import pymysql

# MySql 연결 설정
connection = pymysql.connect(
    host='localhost',
    user='root',
    password='1234',
    database='bitcoin'
)

# 커서 생성
cursor = connection.cursor()

# 데이터 삽입 쿼리
sql = "INSERT INTO predictions (trade_date, prediction) VALUES (%s, %s)"

# 데이터 삽입 실행
cursor.execute(sql, (y_pred_dict['trade_date'][0], y_pred_dict['prediction'][0]))

# 변경 사항 저장
connection.commit()

# 연결 종료
cursor.close()
connection.close()

# %%
from flask import Flask, render_template, request, jsonify
import logging
import pandas as pd
import threading
import time
from model import model_prediction
from database import mysql_connection
from upbitapi import collect_realtime_data

logging.basicConfig(level=logging.INFO)
app = Flask(__name__)

@app.route('/')
def job():
    logging.info("데이터 수집 시작")
    collect_realtime_data()

def collect_and_predict():
    
    logging.info("collect_and_predict 실행")
    data = pd.read_csv("data.csv")  # 데이터 로드

    if data.empty:
        logging.info("데이터 비어있습니다")
        return

    # 모델에 데이터 삽입하여 예측
    y_pred_dict = model_prediction(data)
    # 데이터베이스에 삽입
    mysql_connection(y_pred_dict)

def schedule_job():
    def run_schedule():
        while True:
            collect_and_predict()
            time.sleep(180)  # 3분 대기

    schedule_thread = threading.Thread(target=run_schedule) # run_schedule 쓰레드
    schedule_thread.start()

if __name__ == "__main__":
    app.run(debug=True)
# Out:
# CSV 파일 초기화 완료
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1
# C:\Users\SW\Desktop\time-series-da-main\venv\lib\site-packages\IPython\core\interactiveshell.py:3516: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
